# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from joblib import load, dump
from copy import deepcopy
from statistics import mean

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from collections import Counter

# %%
df = pd.read_csv('data/Features.csv')

# %%
df
# Out:
#       rating    variation                                   verified_reviews  \
# 0          5        Black            Bought this for my son and he loves it.
# 1          5        Black  Got this for the bathroom love it we can liste...
# 2          5        Black  I have 3-Dots and 2-Original and this new one ...
# 3          4        Black  Was a little hard to get it to pare up with th...
# 4          5        Black  There's really no dislike for Alexa( dot) I th...
# ...      ...          ...                                                ...
# 2863       5  White  Spot  This product has made my life much simpler wit...
# 2864       4  White  Spot  Don’t use it for much as I thought we would. S...
# 2865       5  White  Spot                  This echo spot is great I love it
# 2866       1  White  Spot  I returnef this item because it does not speak...
# 2867       5  White  Spot  The voice recognition is amazing, perfect comp...
#
#       feedback  review_len        Rn        Rp        Rs        Rc   Rd  \
# 0            1           9  0.169339  0.000000  0.000000  0.006912  0.0
# 1            1          14  0.289766  0.500000  0.600000  0.010753  0.0
# 2            1          18  0.000000  0.378788  0.526515  0.013057  0.0
# 3            1          21  0.000000 -0.239583  0.520833  0.014593  0.0
# 4            1          29  0.027543  0.220000  0.650000  0.022273  0.0
# ...        ...         ...       ...       ...       ...       ...  ...
# 2863         1          46  0.175915  0.340625  0.500000  0.037864  0.0
# 2864         1          45  0.102563  0.106250  0.306250  0.037864  0.0
# 2865         1           8  0.306980  0.650000  0.675000  0.007767  0.0
# 2866         0          10  0.136828  0.000000  0.000000  0.009709  1.0
# 2867         1          10  0.258361  0.800000  0.950000  0.009709  0.0
#
#          Rsc
# 0     0.5719
# 1     0.6369
# 2     0.6369
# 3     0.4279
# 4     0.9297
# ...      ...
# 2863  0.6588
# 2864  0.3182
# 2865  0.8519
# 2866  0.0000
# 2867  0.8176
#
# [2868 rows x 11 columns]

# %%
data_split = pd.crosstab(df['variation'],df['feedback'])
data_split
# Out:
# feedback                       0    1
# variation
# Black                         30  216
# Black  Dot                    28  442
# Black  Plus                   22  215
# Black  Show                   11  228
# Black  Spot                   22  188
# Charcoal Fabric               10  396
# Configuration: Fire TV Stick  20  294
# Heather Gray Fabric            2  143
# Oak Finish                     2   12
# Sandstone Fabric               6   80
# Walnut Finish                  1    8
# White                         15   67
# White  Dot                    10  162
# White  Plus                    6   61
# White  Show                    8   70
# White  Spot                    8   85

# %% [markdown]
# ## Building the training set:
# #### Each review of set1 was compared pairwise with all of the reviews of set0, and vice versa.
# + (Rx, Ry,1) where x∈Set1 and y∈Set0 → Rx is better than Ry
# + (Ry, Rx, 0) where x∈Set1 and y∈Set0 → Ry is worst than Rx

# %%
def building_training_data(df):
    A = df[df['feedback'] == 1]
    A.loc[df['feedback']==1,'join'] = 'j'
    B = df[df['feedback'] == 0]
    B.loc[df['feedback']==0,'join'] = 'j'
    trainset1 = pd.merge(A, B, how='outer', on='join')
    trainset2 = pd.merge(B, A, how='outer', on='join')
    
    trainset = pd.merge(trainset1, trainset2, how='outer')
    return trainset

variation_list = df['variation'].unique()
data_stack = []
for variation in variation_list:
    temp = deepcopy(df[df['variation'] == variation].iloc[:, 2:])
    build_data = building_training_data(temp)
    print(variation, len(temp), len(build_data))
    build_data.drop(columns=['join', 'feedback_y'], inplace=True)
    data = build_data.iloc[:, 1:]
    data['target'] = build_data.iloc[:, 1]
    data_stack.append(data)
# Out:
# Black 246 12960
# Black  Dot 470 24752
# Black  Plus 237 9460
# Black  Show 239 5016
# Black  Spot 210 8272
# Charcoal Fabric  406 7920
# Configuration: Fire TV Stick 314 11760
# Heather Gray Fabric  145 572
# Oak Finish  14 48
# Sandstone Fabric  86 960
# Walnut Finish  9 16
# White 82 2010
# White  Dot 172 3240
# White  Plus 67 732
# White  Show 78 1120
# White  Spot 93 1360

# %%
train = pd.concat(data_stack).reset_index(drop=True)
train.drop(columns=['verified_reviews_y', 'feedback_x'], inplace=True)

# %%
train
# Out:
#        review_len_x      Rn_x  Rp_x  Rs_x      Rc_x  Rd_x   Rsc_x  \
# 0                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 1                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 2                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 3                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 4                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# ...             ...       ...   ...   ...       ...   ...     ...
# 90193            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90194            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90195            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90196            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90197            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
#
#        review_len_y      Rn_y      Rp_y      Rs_y      Rc_y  Rd_y   Rsc_y  \
# 0                54  0.214055 -0.022138  0.426052  0.031490   0.0 -0.4664
# 1                 6  0.185550  0.000000  0.000000  0.004608   1.0  0.0000
# 2                 4  0.000000  0.000000  0.000000  0.003072   1.0  0.0000
# 3                24  0.164727 -0.095833  0.445833  0.016129   0.0  0.2163
# 4                49  0.050128 -0.097070  0.847222  0.033794   1.0 -0.4359
# ...             ...       ...       ...       ...       ...   ...     ...
# 90193           116  0.109905  0.197377  0.486541  0.085437   1.0  0.9256
# 90194            46  0.175915  0.340625  0.500000  0.037864   0.0  0.6588
# 90195            45  0.102563  0.106250  0.306250  0.037864   0.0  0.3182
# 90196             8  0.306980  0.650000  0.675000  0.007767   0.0  0.8519
# 90197            10  0.258361  0.800000  0.950000  0.009709   0.0  0.8176
#
#        target
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 90193       0
# 90194       0
# 90195       0
# 90196       0
# 90197       0
#
# [90198 rows x 15 columns]

# %%
# Split data into X and y
X = train.iloc[:,:-1].values
y = train.iloc[:,-1].values

# Perform train-test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,shuffle = True, stratify = y) 
print("Test Len:",len(X_test)," ",len(y_test))
# Out:
# Test Len: 18040   18040

# %%
train
# Out:
#        review_len_x      Rn_x  Rp_x  Rs_x      Rc_x  Rd_x   Rsc_x  \
# 0                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 1                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 2                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 3                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# 4                 9  0.169339   0.0   0.0  0.006912   0.0  0.5719
# ...             ...       ...   ...   ...       ...   ...     ...
# 90193            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90194            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90195            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90196            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
# 90197            10  0.136828   0.0   0.0  0.009709   1.0  0.0000
#
#        review_len_y      Rn_y      Rp_y      Rs_y      Rc_y  Rd_y   Rsc_y  \
# 0                54  0.214055 -0.022138  0.426052  0.031490   0.0 -0.4664
# 1                 6  0.185550  0.000000  0.000000  0.004608   1.0  0.0000
# 2                 4  0.000000  0.000000  0.000000  0.003072   1.0  0.0000
# 3                24  0.164727 -0.095833  0.445833  0.016129   0.0  0.2163
# 4                49  0.050128 -0.097070  0.847222  0.033794   1.0 -0.4359
# ...             ...       ...       ...       ...       ...   ...     ...
# 90193           116  0.109905  0.197377  0.486541  0.085437   1.0  0.9256
# 90194            46  0.175915  0.340625  0.500000  0.037864   0.0  0.6588
# 90195            45  0.102563  0.106250  0.306250  0.037864   0.0  0.3182
# 90196             8  0.306980  0.650000  0.675000  0.007767   0.0  0.8519
# 90197            10  0.258361  0.800000  0.950000  0.009709   0.0  0.8176
#
#        target
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 90193       0
# 90194       0
# 90195       0
# 90196       0
# 90197       0
#
# [90198 rows x 15 columns]

# %% [markdown]
# # Spot Checking-
# + Linear Model
# + Non-Linear Model
# + Ensemble Model
#
# <hr>
#
# ## Linear Model: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
print("Training Accuracy\n", accuracy_score(y_train,classifier.predict(X_train)))
print("Test Accuracy\n", accuracy_score(y_test,classifier.predict(X_test)))

print('CLASSIFICATION REPORT')
print("Training\n", classification_report(y_train,classifier.predict(X_train)))
print("Test \n", classification_report(y_test,classifier.predict(X_test)))
# Out:
# Training Accuracy
#  0.9037528756340253
# Test Accuracy
#  0.9019955654101995
# CLASSIFICATION REPORT
# Training
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90     36079
#            1       0.90      0.90      0.90     36079
#
#     accuracy                           0.90     72158
#    macro avg       0.90      0.90      0.90     72158
# weighted avg       0.90      0.90      0.90     72158
#
# Test
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      9020
#            1       0.90      0.91      0.90      9020
#
#     accuracy                           0.90     18040
#    macro avg       0.90      0.90      0.90     18040
# weighted avg       0.90      0.90      0.90     18040

# %% [markdown]
# ### Accuracy: 90%
# ### F1-score: 90%

# %% [markdown]
# ## Non-Linear Model: DecisionTree

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()
classifier.fit(X_train,y_train)

print("Training Accuracy\n", accuracy_score(y_train,classifier.predict(X_train)))
print("Test Accuracy\n", accuracy_score(y_test,classifier.predict(X_test)))

print('CLASSIFICATION REPORT')
print("Training\n", classification_report(y_train,classifier.predict(X_train)))
print("Test \n", classification_report(y_test,classifier.predict(X_test)))
# Out:
# Training Accuracy
#  0.9999584245683084
# Test Accuracy
#  0.9977272727272727
# CLASSIFICATION REPORT
# Training
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36079
#            1       1.00      1.00      1.00     36079
#
#     accuracy                           1.00     72158
#    macro avg       1.00      1.00      1.00     72158
# weighted avg       1.00      1.00      1.00     72158
#
# Test
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9020
#            1       1.00      1.00      1.00      9020
#
#     accuracy                           1.00     18040
#    macro avg       1.00      1.00      1.00     18040
# weighted avg       1.00      1.00      1.00     18040

# %% [markdown]
# ## Accuracy: 99%
# ## F1-score: 100%

# %% [markdown]
# ## Ensemble Model: RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=50, n_jobs = -1, oob_score = True,random_state=42)
classifier.fit(X_train,y_train)

print("Training Accuracy\n", accuracy_score(y_train,classifier.predict(X_train)))
print("Test Accuracy\n", accuracy_score(y_test,classifier.predict(X_test)))

print('CLASSIFICATION REPORT')
print("Training\n", classification_report(y_train,classifier.predict(X_train)))
print("Test \n", classification_report(y_test,classifier.predict(X_test)))

print("Test\nConfusion Matrix: \n", confusion_matrix(y_test, classifier.predict(X_test)))
# Out:
# Training Accuracy
#  0.9999584245683084
# Test Accuracy
#  0.9989467849223946
# CLASSIFICATION REPORT
# Training
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36079
#            1       1.00      1.00      1.00     36079
#
#     accuracy                           1.00     72158
#    macro avg       1.00      1.00      1.00     72158
# weighted avg       1.00      1.00      1.00     72158
#
# Test
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9020
#            1       1.00      1.00      1.00      9020
#
#     accuracy                           1.00     18040
#    macro avg       1.00      1.00      1.00     18040
# weighted avg       1.00      1.00      1.00     18040
#
# Test
# Confusion Matrix:
#  [[9016    4]
#  [  15 9005]]

# %% [markdown]
# ## Accuracy: 99%
# ## F1-score: 100%

# %%
## Score of the training dataset obtained using an out-of-bag estimate. This attribute exists only when oob_score is True.
classifier.oob_score_
# Out:
# 0.9990991989800161

# %%
feature_importances = pd.DataFrame(classifier.feature_importances_,
                                   index = train.iloc[:,:-1].columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#               importance
# Rsc_y           0.218825
# Rsc_x           0.206737
# Rp_y            0.137485
# Rp_x            0.122371
# Rc_y            0.054618
# Rc_x            0.053459
# review_len_y    0.045685
# review_len_x    0.041809
# Rs_y            0.037456
# Rs_x            0.027012
# Rn_y            0.022729
# Rn_x            0.019761
# Rd_x            0.006980
# Rd_y            0.005072

# %%
dump(classifier, 'randomforest.joblib', compress = 2)
# Out:
# ['randomforest.joblib']

# %% [markdown]
# ## RandomForest Classifier Weights Saved.
# ### Accuracy: 0.99
# ### oob_score: 0.99

# %% [markdown]
# # PART 2. Model Ranking Metric
#
# ### Accuracy of Ranking Methodology
# ### `Ranking Accuracy on Single Product = Number of 1s found in first x positions / x`

# %%
classifier = load('randomforest.joblib')

# %%
variation_list = df['variation'].unique()
df['win']=0
df['lose']=0
df['review_score'] = 0.0
df.reset_index(inplace = True, drop = True)


def score_giver(C,D):
    E = pd.merge(C,D,how='outer',on='j')
    E.drop(columns=['j', 'feedback_x', 'feedback_y'],inplace = True)
    q = classifier.predict(E.values)
    return Counter(q)

for variation in variation_list:
    data = df[df['variation']==variation]
    for indx in data.index:
        review = df.iloc[indx, 3:-3]
        review['j'] = 'jn'
        C = pd.DataFrame([review])
        D = data[data.index!=indx].iloc[:,3:-3]
        D['j'] = 'jn'
        score = score_giver(C,D)
        df.at[indx, 'win'] = 0 if score.get(1) is None else score.get(1)
        df.at[indx, 'lose'] = 0 if score.get(0) is None else score.get(0)
        df.at[indx, 'review_score'] = float(0 if score.get(1) is None else score.get(1)) / len(data) * 1.0

df = df.sort_values(by = ['variation','review_score'], ascending = False)

r_accuracy =[]
for variation in variation_list:
    x = data_split[data_split.index == variation][1][0]
    number_of_1_in_x = Counter(df[df['variation']==variation].iloc[:x, ]['feedback']).get(1)
    rank_accuracy = float(number_of_1_in_x*1.0 / x*1.0)
    print("Variation: {} | Rank Accuracy: {}".format(variation, rank_accuracy))
    r_accuracy.append(rank_accuracy)
print("Mean Rank Accuracy: {}".format(mean(r_accuracy)))
# Out:
# Variation: Black | Rank Accuracy: 0.9953703703703703
# Variation: Black  Dot | Rank Accuracy: 1.0
# Variation: Black  Plus | Rank Accuracy: 1.0
# Variation: Black  Show | Rank Accuracy: 1.0
# Variation: Black  Spot | Rank Accuracy: 0.9946808510638298
# Variation: Charcoal Fabric  | Rank Accuracy: 1.0
# Variation: Configuration: Fire TV Stick | Rank Accuracy: 0.9965986394557823
# Variation: Heather Gray Fabric  | Rank Accuracy: 1.0
# Variation: Oak Finish  | Rank Accuracy: 1.0
# Variation: Sandstone Fabric  | Rank Accuracy: 1.0
# Variation: Walnut Finish  | Rank Accuracy: 1.0
# Variation: White | Rank Accuracy: 1.0
# Variation: White  Dot | Rank Accuracy: 1.0
# Variation: White  Plus | Rank Accuracy: 0.9836065573770492
# Variation: White  Show | Rank Accuracy: 0.9857142857142858
# Variation: White  Spot | Rank Accuracy: 1.0
# Mean Rank Accuracy: 0.9972481689988323

# %%
df.drop(columns=['rating'], inplace=True)
df
# Out:
#         variation                                   verified_reviews  \
# 2815  White  Spot                            Awesome cute and smart!
# 2823  White  Spot                               Excellent purchase!!
# 2837  White  Spot                                             Great!
# 2848  White  Spot  Awesome. I love that it shows the lyrics of so...
# 2797  White  Spot                  very nice gadget. love it's look.
# ...           ...                                                ...
# 150         Black  I wanted to use these as a radio and intercom ...
# 156         Black  Great product but returning for new Alexa Dot....
# 171         Black  I set up the Echo Dot and it worked for an hou...
# 164         Black  &#34;NEVER BUY CERTIFIED AND REFURBISHED ECHO ...
# 170         Black  This Echo Dot is horrible. The volume on my ph...
#
#       feedback  review_len        Rn        Rp        Rs        Rc   Rd  \
# 2815         1           4  0.000000  0.589286  0.880952  0.003883  0.0
# 2823         1           2  0.000000  1.000000  1.000000  0.001942  0.0
# 2837         1           1  0.000000  1.000000  0.750000  0.000971  0.0
# 2848         1          10  0.000000  0.812500  0.800000  0.009709  0.0
# 2797         1           6  0.320980  0.640000  0.800000  0.005825  0.0
# ...        ...         ...       ...       ...       ...       ...  ...
# 150          0         114  0.151737 -0.187626  0.466667  0.068356  0.0
# 156          0          16  0.061529  0.468182  0.602273  0.012289  0.0
# 171          0          30  0.150869 -0.061035  0.200000  0.019201  1.0
# 164          0          65  0.338623 -0.461212  0.661515  0.039171  0.0
# 170          0          26  0.175931 -1.000000  1.000000  0.016897  0.0
#
#          Rsc  win  lose  review_score
# 2815  0.8777   91     1      0.978495
# 2823  0.6467   91     1      0.978495
# 2837  0.6588   91     1      0.978495
# 2848  0.8622   90     2      0.967742
# 2797  0.8204   89     3      0.956989
# ...      ...  ...   ...           ...
# 150  -0.9433    4   241      0.016260
# 156   0.2732    4   241      0.016260
# 171  -0.6973    4   241      0.016260
# 164  -0.8253    3   242      0.012195
# 170  -0.5423    0   245      0.000000
#
# [2868 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# Sort the dataframe by variation and review score
df_sorted = df.sort_values(by=['variation', 'review_score'], ascending=[False, False])

# Group the dataframe by variation and calculate the mean review score
grouped_df = df_sorted.groupby('variation')['review_score'].mean()

# Get the variation names and corresponding mean review scores
variations = grouped_df.index
mean_scores = grouped_df.values

# Create a line plot
plt.plot(variations, mean_scores, marker='o')

# Set labels and title
plt.xlabel('Variation')
plt.ylabel('Mean Review Score')
plt.title('Pairwise Ranking Scores')

# Rotate x-axis labels if needed
plt.xticks(rotation=75)

# Show the plot
plt.show()

# %%
df.iloc[:, [0,1,-1]].to_csv('data/train_ranked_output.csv',index = False)
